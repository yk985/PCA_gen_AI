# %%
from trainer_PCA_cond import trainer_PCA_cond, trainer_PCAcondJ
from model_PCA_cond import ModelPCACond
#from attetion_sep_size_heads import trainer_multidomain_strategy
from attention import trainer, trainer_PCA_comp_brute_force, trainer_PCA_comp_2_model, ar_trainer

import os
import torch
import random
import numpy as np

cwd = os.getcwd()
def save_tensor_to_txt(tensor, filename):
    with open(filename, 'w') as f:
        # Write tensor dimensions
        dims = tensor.size()
        f.write(" ".join(map(str, dims)) + "\n")

        # Iterate over the first dimension (slices)
        for i in range(dims[0]):
            f.write("\n")
            f.write(f"Slice {i + 1}\n")
            for j in range(dims[1]):  # Iterate over the second dimension (rows)
                row = tensor[i, j].tolist()
                f.write(",".join(map(str, row)) + "\n")
cwd=cwd.replace(r"/CODE/AttentionDCA_python/src",'')

nb_bins_PCA=35
H = 64
d= 10
Nbins=35
n_epochs = 500 #could go more down
#domain1_end = 63 #if your protein msa input family has a domain division, this is the zero index of the last aminoacid of the first domain
domain1_end = 62
filename = cwd + r'/CODE/DataAttentionDCA/jdoms/jdoms_bacteria_train2.fasta' #new lisa for energy couplings: HKRR174
structfile = None
trainer_type = 'std' # 'std' or 'std_with_masks' 'multidomain'
family = 'jdoms'

if trainer_type == 'std':
    domain1_end = 0
    H1 = H2 = 0

if trainer_type == 'std' or trainer_type == 'std_with_masks':

    model = ar_trainer(
        n_epochs=n_epochs,
        H=H,
        d=d,
        #Nbins=Nbins,
        #Ncomp=2,
        eta=0.005,
        filename=filename,
        structfile=structfile,
        losstype='without_J',
        index_last_domain1=domain1_end,  # this value is the 0-index include the domain 1, for HK-RR is 63 (so 64 long domain 1) 
        #it is set to zero if i dont want to divide any domain
        H1 = H1,
        H2 = H2,
        max_gap_frac=0.8,
    )


    # Create results directory
    simul_name = f'{H}_{d}_{family}_without_J_{n_epochs}_AR'
    results_dir = f'./results/{simul_name}'
    os.makedirs(results_dir, exist_ok=True)

    # Save model parameters
    save_tensor_to_txt(model.Q.data, "./results/"+simul_name+"/Q_tensor.txt")
    save_tensor_to_txt(model.K.data, "./results/"+simul_name+"/K_tensor.txt")
    save_tensor_to_txt(model.V.data, "./results/"+simul_name+"/V_tensor.txt")
# Out:
# Total sequences read: 14502
# Sequences after filtering: 14502
# Sampling 100000 pairs out of 105146751 total pairs.
# Mean fraction of identical positions (sampled): 0.3721593650793651
# Computed theta: 0.3267417440215917
# 100%|██████████| 14502/14502 [00:07<00:00, 1852.69it/s]
# 3265.70225762244
# 63
# Using device: cpu
# Epoch 1 - Train Loss: 530.7964, Val Loss: 179.4741
# Epoch 2 - Train Loss: 330.6789, Val Loss: 111.1331
# Epoch 3 - Train Loss: 242.8945, Val Loss: 75.5730
# Epoch 4 - Train Loss: 199.0474, Val Loss: 56.7692
# Epoch 5 - Train Loss: 175.0258, Val Loss: 46.1321
# Epoch 6 - Train Loss: 160.2501, Val Loss: 39.3365
# Epoch 7 - Train Loss: 150.2726, Val Loss: 34.6105
# EarlyStopping counter: 1 out of 10
# Epoch 95 - Train Loss: 100.9215, Val Loss: 12.2089
# Epoch 96 - Train Loss: 100.8836, Val Loss: 12.2035
# Epoch 97 - Train Loss: 100.7919, Val Loss: 12.1678
# Epoch 98 - Train Loss: 100.7331, Val Loss: 12.1817
# EarlyStopping counter: 1 out of 10
# Epoch 99 - Train Loss: 100.7002, Val Loss: 12.1592
# Epoch 100 - Train Loss: 100.5814, Val Loss: 12.1276
# Epoch 101 - Train Loss: 100.6214, Val Loss: 12.1426
# EarlyStopping counter: 1 out of 10
# Epoch 102 - Train Loss: 100.5275, Val Loss: 12.0948
# Epoch 103 - Train Loss: 100.4139, Val Loss: 12.1353
# EarlyStopping counter: 1 out of 10
# Epoch 104 - Train Loss: 100.3972, Val Loss: 12.1004
# EarlyStopping counter: 2 out of 10
# Epoch 105 - Train Loss: 100.3594, Val Loss: 12.0770
# Epoch 106 - Train Loss: 100.2453, Val Loss: 12.0819
# EarlyStopping counter: 1 out of 10
# Epoch 107 - Train Loss: 100.2110, Val Loss: 12.0776
# EarlyStopping counter: 2 out of 10
# Epoch 108 - Train Loss: 100.2373, Val Loss: 12.0803
# EarlyStopping counter: 3 out of 10
# Epoch 109 - Train Loss: 100.0766, Val Loss: 12.0345
# Epoch 110 - Train Loss: 100.0438, Val Loss: 12.0580
# EarlyStopping counter: 1 out of 10
# Epoch 111 - Train Loss: 100.0498, Val Loss: 12.0420
# EarlyStopping counter: 2 out of 10
# Epoch 112 - Train Loss: 99.8890, Val Loss: 12.0125
# Epoch 113 - Train Loss: 99.8884, Val Loss: 12.0267
# EarlyStopping counter: 1 out of 10
# Epoch 114 - Train Loss: 99.8354, Val Loss: 12.0050
# Epoch 115 - Train Loss: 99.8193, Val Loss: 11.9919
# Epoch 116 - Train Loss: 99.7501, Val Loss: 11.9992
# EarlyStopping counter: 1 out of 10
# Epoch 117 - Train Loss: 99.6613, Val Loss: 11.9991
# EarlyStopping counter: 2 out of 10
# Epoch 118 - Train Loss: 99.6412, Val Loss: 11.9604
# Epoch 119 - Train Loss: 99.5906, Val Loss: 11.9800
# EarlyStopping counter: 1 out of 10
# Epoch 120 - Train Loss: 99.5915, Val Loss: 11.9516
# Epoch 121 - Train Loss: 99.5140, Val Loss: 11.9477
# Epoch 122 - Train Loss: 99.5065, Val Loss: 11.9534
# EarlyStopping counter: 1 out of 10
# Epoch 123 - Train Loss: 99.3829, Val Loss: 11.9427
# Epoch 124 - Train Loss: 99.3713, Val Loss: 11.9342
# Epoch 125 - Train Loss: 99.3848, Val Loss: 11.9204
# Epoch 126 - Train Loss: 99.2999, Val Loss: 11.9317
# EarlyStopping counter: 1 out of 10
# Epoch 127 - Train Loss: 99.1872, Val Loss: 11.9040
# Epoch 128 - Train Loss: 99.2523, Val Loss: 11.9132
# EarlyStopping counter: 1 out of 10
# Epoch 129 - Train Loss: 99.1606, Val Loss: 11.9108
# EarlyStopping counter: 2 out of 10
# Epoch 130 - Train Loss: 99.0589, Val Loss: 11.8783
# Epoch 131 - Train Loss: 99.0960, Val Loss: 11.8914
# EarlyStopping counter: 1 out of 10
# Epoch 132 - Train Loss: 99.0121, Val Loss: 11.8786
# EarlyStopping counter: 2 out of 10
# Epoch 133 - Train Loss: 99.0325, Val Loss: 11.8768
# Epoch 134 - Train Loss: 98.9945, Val Loss: 11.8800
# EarlyStopping counter: 1 out of 10
# Epoch 135 - Train Loss: 98.9618, Val Loss: 11.8736
# Epoch 136 - Train Loss: 98.9433, Val Loss: 11.8540
# Epoch 137 - Train Loss: 98.9115, Val Loss: 11.8667
# EarlyStopping counter: 1 out of 10
# Epoch 138 - Train Loss: 98.8707, Val Loss: 11.8468
# Epoch 139 - Train Loss: 98.8250, Val Loss: 11.8448
# Epoch 140 - Train Loss: 98.8435, Val Loss: 11.8640
# EarlyStopping counter: 1 out of 10
# Epoch 141 - Train Loss: 98.7497, Val Loss: 11.8346
# Epoch 142 - Train Loss: 98.6738, Val Loss: 11.8219
# Epoch 143 - Train Loss: 98.6891, Val Loss: 11.8479
# EarlyStopping counter: 1 out of 10
# Epoch 144 - Train Loss: 98.6624, Val Loss: 11.8032
# Epoch 145 - Train Loss: 98.6013, Val Loss: 11.8337
# EarlyStopping counter: 1 out of 10
# Epoch 146 - Train Loss: 98.5350, Val Loss: 11.8115
# EarlyStopping counter: 2 out of 10
# Epoch 147 - Train Loss: 98.5643, Val Loss: 11.8209
# EarlyStopping counter: 3 out of 10
# Epoch 148 - Train Loss: 98.5086, Val Loss: 11.8127
# EarlyStopping counter: 4 out of 10
# Epoch 149 - Train Loss: 98.4448, Val Loss: 11.8115
# EarlyStopping counter: 5 out of 10
# Epoch 150 - Train Loss: 98.4573, Val Loss: 11.8138
# EarlyStopping counter: 6 out of 10
# Epoch 151 - Train Loss: 98.3962, Val Loss: 11.8083
# EarlyStopping counter: 7 out of 10
# Epoch 152 - Train Loss: 98.3501, Val Loss: 11.8013
# Epoch 153 - Train Loss: 98.3556, Val Loss: 11.7970
# Epoch 154 - Train Loss: 98.2910, Val Loss: 11.7892
# Epoch 155 - Train Loss: 98.2234, Val Loss: 11.8138
# EarlyStopping counter: 1 out of 10
# Epoch 156 - Train Loss: 98.1930, Val Loss: 11.7778
# Epoch 157 - Train Loss: 98.2436, Val Loss: 11.7701
# Epoch 158 - Train Loss: 98.2504, Val Loss: 11.7946
# EarlyStopping counter: 1 out of 10
# Epoch 159 - Train Loss: 98.1525, Val Loss: 11.7755
# EarlyStopping counter: 2 out of 10
# Epoch 160 - Train Loss: 98.1488, Val Loss: 11.7726
# EarlyStopping counter: 3 out of 10
# Epoch 161 - Train Loss: 98.0884, Val Loss: 11.7689
# Epoch 162 - Train Loss: 98.0975, Val Loss: 11.7627
# Epoch 163 - Train Loss: 98.0296, Val Loss: 11.7863
# EarlyStopping counter: 1 out of 10
# Epoch 164 - Train Loss: 98.0512, Val Loss: 11.7603
# Epoch 165 - Train Loss: 97.9685, Val Loss: 11.7655
# EarlyStopping counter: 1 out of 10
# Epoch 166 - Train Loss: 97.9694, Val Loss: 11.7582
# Epoch 167 - Train Loss: 97.9583, Val Loss: 11.7691
# EarlyStopping counter: 1 out of 10
# Epoch 168 - Train Loss: 97.9365, Val Loss: 11.7676
# EarlyStopping counter: 2 out of 10
# Epoch 169 - Train Loss: 97.9644, Val Loss: 11.7521
# Epoch 170 - Train Loss: 97.8734, Val Loss: 11.7416
# Epoch 171 - Train Loss: 97.8882, Val Loss: 11.7481
# EarlyStopping counter: 1 out of 10
# Epoch 172 - Train Loss: 97.8568, Val Loss: 11.7569
# EarlyStopping counter: 2 out of 10
# Epoch 173 - Train Loss: 97.7857, Val Loss: 11.7434
# EarlyStopping counter: 3 out of 10
# Epoch 174 - Train Loss: 97.7478, Val Loss: 11.7442
# EarlyStopping counter: 4 out of 10
# Epoch 175 - Train Loss: 97.7969, Val Loss: 11.7545
# EarlyStopping counter: 5 out of 10
# Epoch 176 - Train Loss: 97.7266, Val Loss: 11.7263
# Epoch 177 - Train Loss: 97.6860, Val Loss: 11.7164
# Epoch 178 - Train Loss: 97.6823, Val Loss: 11.7393
# EarlyStopping counter: 1 out of 10
# Epoch 179 - Train Loss: 97.6735, Val Loss: 11.7390
# EarlyStopping counter: 2 out of 10
# Epoch 180 - Train Loss: 97.6731, Val Loss: 11.7145
# Epoch 181 - Train Loss: 97.5687, Val Loss: 11.7352
# EarlyStopping counter: 1 out of 10
# Epoch 182 - Train Loss: 97.5489, Val Loss: 11.7085
# Epoch 183 - Train Loss: 97.6004, Val Loss: 11.7290
# EarlyStopping counter: 1 out of 10
# Epoch 184 - Train Loss: 97.5437, Val Loss: 11.6941
# Epoch 185 - Train Loss: 97.5332, Val Loss: 11.7252
# EarlyStopping counter: 1 out of 10
# Epoch 186 - Train Loss: 97.5368, Val Loss: 11.7131
# EarlyStopping counter: 2 out of 10
# Epoch 187 - Train Loss: 97.5038, Val Loss: 11.7109
# EarlyStopping counter: 3 out of 10
# Epoch 188 - Train Loss: 97.4418, Val Loss: 11.7153
# EarlyStopping counter: 4 out of 10
# Epoch 189 - Train Loss: 97.4483, Val Loss: 11.7070
# EarlyStopping counter: 5 out of 10
# Epoch 190 - Train Loss: 97.4127, Val Loss: 11.7087
# EarlyStopping counter: 6 out of 10
# Epoch 191 - Train Loss: 97.4066, Val Loss: 11.7280
# EarlyStopping counter: 7 out of 10
# Epoch 192 - Train Loss: 97.4033, Val Loss: 11.7088
# EarlyStopping counter: 8 out of 10
# Epoch 193 - Train Loss: 97.3648, Val Loss: 11.7078
# EarlyStopping counter: 9 out of 10
# Epoch 194 - Train Loss: 97.3265, Val Loss: 11.7347
# EarlyStopping counter: 10 out of 10
# Early stopping triggered.
# Final Test Loss: 11.7347
